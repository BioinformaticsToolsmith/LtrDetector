# %%
# %matplotlib nbagg

# %%
from graphs import Graphs

# %%
graphs = Graphs("output/trialResults.csv")

# %%
graphs.plotParam('min_dist')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graphs.plotParam('max_dist')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graphs.plotParam('min_plat_len')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graphs.plotParam('diff_thresh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graphs.plotParam('gap_tol')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graphs.plotTrials()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9a1be8f3098a> in <module>()
# ----> 1 graphs.plotTrials()
#
# /home/joseph/Projects/ltr/src/graphs.py in plotTrials(self)
#      21     def plotTrials(self):
#      22         my_title = str("trial")+" vs."+str(self.sort_col)
# ---> 23         self.data.reset_index.plot(x = 'index', y = self.sort_col,kind="scatter",title = my_title)
#      24         plt.show()
#      25
#
# AttributeError: 'function' object has no attribute 'plot'
